# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
raw_data = pd.read_csv(r"C:\Users\user\Desktop\MAL Anime Top 10000 Details.csv.zip")
new_data = pd.DataFrame(raw_data[["Anime Title","Type","Episodes","Aired","Producers","Studios",
                                  "Source","Genres","Score","Members","Favorites"]])
TV_data = new_data.loc[new_data["Type"]=="TV"]
Movie_data = new_data.loc[new_data["Type"]=="Movie"]

# %% [markdown]
# Anime Title - title of the anime
#
# Type - Type of anime(OVA/TV/etc)
#
# Episodes - number of episodes
#
# Aired - time frame of airing
#
# Producers - producers of the anime
#
# Studios - studio responsible for anime creation
#
# Source - source from which anime was adapted from
#
# Genres - genre of anime
#
# Score - MAL score for the anime to perform uni-varaiate analysis
#
# Members - number of members registered for anime to perform uni-varaiate analysis
#
# Favourites - number of members who favourited the anime to perform uni-varaiate analysis
#
# TO DO
#
# Create a new column as percentage of favourites out of all members DONE
#
# Use studio/source/genre as entry varaibles

# %%
sb.catplot(y = 'Studios', data = TV_data[TV_data.groupby('Studios').Studios.transform('count') > 25], kind='count')

# %%
TV_Studios_array=TV_data["Studios"].unique()
np.where(TV_Studios_array == TV_data["Studios"].iloc[27])[0][0]
# Out:
# 11

# %%
TV_data["Genres"].iloc[0]
# Out:
# 'Action, Military, Adventure, Comedy, Drama, Magic, Fantasy, Shounen'

# %% [markdown]
# # 08/03
# ## Convert source to int and compress them together
# ## Extracted genre top 2
# ## Converted genre from str to int, added genre_reference_1 and genre_reference_2
# ## Converted Aired to Season (1= Winter)
# ## Ran LinReg on 5 predictors, obtained R^2 = 0.39
#
# ### To-do
# ### Clean studio (some NULL)
# ### Modify dectree

# %%
source = TV_data['Source']
genres = TV_data['Genres']
score = TV_data['Score']
members = pd.DataFrame(TV_data['Members'])
fav = TV_data['Favorites']
studios = TV_data['Studios']

# %%
TV_data.insert(loc=11, column='Fav%', value=round(TV_data['Favorites']*100/TV_data['Members'], 3))

# %%
source.unique()
# Out:
# array(['Manga', 'Visual novel', 'Light novel', 'Original', 'Web manga',
#        'Novel', '4-koma manga', 'Card game', 'Book', 'Game', 'Other',
#        'Unknown', 'Music', 'Picture book', 'Digital manga', 'Radio'],
#       dtype=object)

# %% [markdown]
# Convert source to an int, total of 16 sources. Compress some sources together
#
# 0 - All manga + Picture book
#
# 1 - Novel, Light Novel, Book
#
# 2 - All game + Visual novel
#
# 3 - Other + Unknown
#
# 4 - Music + Radio
#
# 5 - Original

# %%
source_list = source.tolist() #list of sources based on index in Tv_data
source_list_unique = ["Manga", "Novel", "Game", "Other", "Audio", "Original"] #compresed source_reference list

# %%
a = [0] * len(TV_data)
for i in range(len(source_list)):
    if source_list[i] in ["Manga", "Web manga", "4-koma manga", "Digital manga", "Picture book"]:
        a[i] = source_list_unique.index("Manga")
    elif source_list[i] in ["Visual novel", "Light novel", "Book"]:
        a[i] = source_list_unique.index("Novel")
    elif source_list[i] in ["Card game", "Game", "Visual novel"]:
        a[i] = source_list_unique.index("Game")
    elif source_list[i] in ["Other", "Unknown"]:
        a[i] = source_list_unique.index("Other")
    elif source_list[i] in ["Radio", "Music"]:
        a[i] = source_list_unique.index("Audio")
    elif source_list[i] == "Original":
        a[i] = source_list_unique.index("Original")
TV_data["Source_reference"] = a
# Out:
# <ipython-input-10-a395e17582c5>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TV_data["Source_reference"] = a

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import plot_tree 

def decTree(y, x, depth):
    X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.2)    
    dectree = DecisionTreeClassifier(max_depth = depth)
    dectree.fit(X_train, Y_train)
    Y_train_pred = dectree.predict(X_train)
    Y_test_pred = dectree.predict(X_test)
    cm = confusion_matrix(Y_train, Y_train_pred)
    TP = cm[1][1]/(cm[1][1] + cm[1][0])
    FP = cm[0][1]/(cm[0][1] + cm[0][0])
    cm1 = confusion_matrix(Y_test, Y_test_pred)
    TP1 = cm1[1][1]/(cm1[1][1] + cm1[1][0])
    FP1 = cm1[0][1]/(cm1[0][1] + cm1[0][0])
    print("Goodness of Fit of Model \tTrain Dataset")
    print("Classification Accuracy \t:", dectree.score(X_train, Y_train))
    #print("True Positive Rate \t:", TP)
    #print("False Positive Rate\t:", FP)
    print()
    print("Goodness of Fit of Model \tTest Dataset")
    print("Classification Accuracy \t:", dectree.score(X_test, Y_test))
    #print("True Positive Rate \t:", TP1)
    #print("False Positive Rate\t:", FP1)
    print()
    f, axes = plt.subplots(1, 2, figsize=(24, 48))
    sb.heatmap(confusion_matrix(Y_train, Y_train_pred),
               annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
    sb.heatmap(confusion_matrix(Y_test, Y_test_pred), 
               annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
    f = plt.figure(figsize=(48,48))
    plot_tree(dectree, filled=True, rounded=True, 
              feature_names="Fav%", 
              class_names=["0","1","2","3","4","5"])

# %%
decTree(TV_data["Source_reference"].iloc[:999].to_numpy().reshape(-1,1),TV_data["Fav%"].iloc[:999].to_numpy().reshape(-1,1),3)
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.5957446808510638
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.58

# %%
genres_list_unique = [0] * 100
index = 0;
for i in range(len(genres)):
    temp_list = genres.iloc[i].split(",")
    for element in temp_list:
        if(element.strip() not in genres_list_unique):
            genres_list_unique[index] = element.strip()
            index += 1
genres_list_unique = [i for i in genres_list_unique if i != 0] 
genres_list_unique.insert(0, "Null") #genres_list_unique contains all possible genre, first index is NULL(no genre)

# %%
a = [0] * len(TV_data)
b = [0] * len(TV_data)
for i in range(len(TV_data)):
    word = TV_data["Genres"].iloc[i].split(",")
    a[i] = genres_list_unique.index(word[0].strip())
    if(len(word)>1):
        b[i] = genres_list_unique.index(word[1].strip())

# %%
TV_data["genre_reference_1"] = a
TV_data["genre_reference_2"] = b
TV_data
# Out:
# <ipython-input-15-8bc38560b612>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TV_data["genre_reference_1"] = a
# <ipython-input-15-8bc38560b612>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TV_data["genre_reference_2"] = b
#                            Anime Title Type Episodes  \
# 0     Fullmetal Alchemist: Brotherhood   TV       64
# 1                          Steins;Gate   TV       24
# 2                             Gintama°   TV       51
# 3               Hunter x Hunter (2011)   TV      148
# 5                             Gintama'   TV       51
# ...                                ...  ...      ...
# 9978                         Barom One   TV       13
# 9983                    Kurayami Santa   TV       13
# 9985    Omae wa Mada Gunma wo Shiranai   TV       12
# 9987                      Peeping Life   TV       10
# 9999            Kamikaze Kaitou Jeanne   TV       44
#
#                              Aired  \
# 0       Apr 5, 2009 to Jul 4, 2010
# 1      Apr 6, 2011 to Sep 14, 2011
# 2      Apr 8, 2015 to Mar 30, 2016
# 3      Oct 2, 2011 to Sep 24, 2014
# 5      Apr 4, 2011 to Mar 26, 2012
# ...                            ...
# 9978   Dec 7, 2002 to Mar 22, 2003
# 9983   Jul 5, 2015 to Sep 27, 2015
# 9985   Apr 2, 2018 to Jun 18, 2018
# 9987  May 14, 2009 to Aug 11, 2009
# 9999  Feb 13, 1999 to Jan 29, 2000
#
#                                               Producers  \
# 0     Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 1     Frontier Works, Media Factory, Movic, AT-X, Ka...
# 2                             TV Tokyo, Aniplex, Dentsu
# 3              VAP, Nippon Television Network, Shueisha
# 5     TV Tokyo, Aniplex, Dentsu, Trinity Sound, Mira...
# ...                                                 ...
# 9978                                               AT-X
# 9983                                                NaN
# 9985                                     TOHO animation
# 9987                                   CoMix Wave Films
# 9999                                                NaN
#
#                     Studios        Source  \
# 0                     Bones         Manga
# 1                 White Fox  Visual novel
# 2     Bandai Namco Pictures         Manga
# 3                  Madhouse         Manga
# 5                   Sunrise         Manga
# ...                     ...           ...
# 9978              E&G Films         Manga
# 9983                   ILCA      Original
# 9985       Asahi Production     Web manga
# 9987                    NaN      Original
# 9999         Toei Animation         Manga
#
#                                                  Genres  Score  Members  \
# 0     Action, Military, Adventure, Comedy, Drama, Ma...   9.22  2025613
# 1                                      Thriller, Sci-Fi   9.12  1636151
# 2     Action, Comedy, Historical, Parody, Samurai, S...   9.11   363879
# 3      Action, Adventure, Fantasy, Shounen, Super Power   9.11  1459320
# 5     Action, Sci-Fi, Comedy, Historical, Parody, Sa...   9.08   337198
# ...                                                 ...    ...      ...
# 9978              Action, Sci-Fi, Supernatural, Shounen   5.25     1576
# 9983                           Historical, Supernatural   5.25     2392
# 9985                                     Comedy, School   5.25    11760
# 9987                              Slice of Life, Comedy   5.25     2481
# 9999  Adventure, Comedy, Demons, Drama, Fantasy, Mag...   7.45    44497
#
#       Favorites   Fav%  Source_reference  genre_reference_1  genre_reference_2
# 0        167812  8.285                 0                  1                  2
# 1        139909  8.551                 1                  9                 10
# 2         10353  2.845                 0                  1                  4
# 3        130492  8.942                 0                  1                  3
# 5          6013  1.783                 0                  1                 10
# ...         ...    ...               ...                ...                ...
# 9978          1  0.063                 0                  1                 10
# 9983          6  0.251                 5                 11                 19
# 9985          2  0.017                 0                  4                 24
# 9987          3  0.121                 5                 18                  4
# 9999        478  1.074                 0                  3                  4
#
# [3681 rows x 15 columns]

# %%
c = [0] * len(TV_data)
for i  in range(len(TV_data)):
    temp = TV_data["Aired"].iloc[i][:3]
    if temp == 'Jan' or temp == 'Feb' or temp == 'Mar': #Winter
        c[i] = 1
    elif temp == 'Apr' or temp == 'May' or temp == 'Jun': #Spring
        c[i] = 2
    elif temp == 'Jul' or temp == 'Aug' or temp == 'Sep': # Summer
        c[i] = 3
    else:                                                #Autumn/Fall(americans)
        c[i] = 4
TV_data["Season"] = c
TV_data
# Out:
# <ipython-input-16-f503446a6c22>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TV_data["Season"] = c
#                            Anime Title Type Episodes  \
# 0     Fullmetal Alchemist: Brotherhood   TV       64
# 1                          Steins;Gate   TV       24
# 2                             Gintama°   TV       51
# 3               Hunter x Hunter (2011)   TV      148
# 5                             Gintama'   TV       51
# ...                                ...  ...      ...
# 9978                         Barom One   TV       13
# 9983                    Kurayami Santa   TV       13
# 9985    Omae wa Mada Gunma wo Shiranai   TV       12
# 9987                      Peeping Life   TV       10
# 9999            Kamikaze Kaitou Jeanne   TV       44
#
#                              Aired  \
# 0       Apr 5, 2009 to Jul 4, 2010
# 1      Apr 6, 2011 to Sep 14, 2011
# 2      Apr 8, 2015 to Mar 30, 2016
# 3      Oct 2, 2011 to Sep 24, 2014
# 5      Apr 4, 2011 to Mar 26, 2012
# ...                            ...
# 9978   Dec 7, 2002 to Mar 22, 2003
# 9983   Jul 5, 2015 to Sep 27, 2015
# 9985   Apr 2, 2018 to Jun 18, 2018
# 9987  May 14, 2009 to Aug 11, 2009
# 9999  Feb 13, 1999 to Jan 29, 2000
#
#                                               Producers  \
# 0     Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 1     Frontier Works, Media Factory, Movic, AT-X, Ka...
# 2                             TV Tokyo, Aniplex, Dentsu
# 3              VAP, Nippon Television Network, Shueisha
# 5     TV Tokyo, Aniplex, Dentsu, Trinity Sound, Mira...
# ...                                                 ...
# 9978                                               AT-X
# 9983                                                NaN
# 9985                                     TOHO animation
# 9987                                   CoMix Wave Films
# 9999                                                NaN
#
#                     Studios        Source  \
# 0                     Bones         Manga
# 1                 White Fox  Visual novel
# 2     Bandai Namco Pictures         Manga
# 3                  Madhouse         Manga
# 5                   Sunrise         Manga
# ...                     ...           ...
# 9978              E&G Films         Manga
# 9983                   ILCA      Original
# 9985       Asahi Production     Web manga
# 9987                    NaN      Original
# 9999         Toei Animation         Manga
#
#                                                  Genres  Score  Members  \
# 0     Action, Military, Adventure, Comedy, Drama, Ma...   9.22  2025613
# 1                                      Thriller, Sci-Fi   9.12  1636151
# 2     Action, Comedy, Historical, Parody, Samurai, S...   9.11   363879
# 3      Action, Adventure, Fantasy, Shounen, Super Power   9.11  1459320
# 5     Action, Sci-Fi, Comedy, Historical, Parody, Sa...   9.08   337198
# ...                                                 ...    ...      ...
# 9978              Action, Sci-Fi, Supernatural, Shounen   5.25     1576
# 9983                           Historical, Supernatural   5.25     2392
# 9985                                     Comedy, School   5.25    11760
# 9987                              Slice of Life, Comedy   5.25     2481
# 9999  Adventure, Comedy, Demons, Drama, Fantasy, Mag...   7.45    44497
#
#       Favorites   Fav%  Source_reference  genre_reference_1  \
# 0        167812  8.285                 0                  1
# 1        139909  8.551                 1                  9
# 2         10353  2.845                 0                  1
# 3        130492  8.942                 0                  1
# 5          6013  1.783                 0                  1
# ...         ...    ...               ...                ...
# 9978          1  0.063                 0                  1
# 9983          6  0.251                 5                 11
# 9985          2  0.017                 0                  4
# 9987          3  0.121                 5                 18
# 9999        478  1.074                 0                  3
#
#       genre_reference_2  Season
# 0                     2       2
# 1                    10       2
# 2                     4       2
# 3                     3       4
# 5                    10       2
# ...                 ...     ...
# 9978                 10       4
# 9983                 19       3
# 9985                 24       2
# 9987                  4       2
# 9999                  4       1
#
# [3681 rows x 16 columns]

# %%
studio_reference_unique = [0] * 335
index = 0
for i in range(len(TV_data)):
    temp = studios.iloc[i]
    if(isinstance(temp,str)):
        temp = temp.split(",")
        for j in range(len(temp)):
            if(temp[j].strip() not in studio_reference_unique):
                studio_reference_unique[index] = temp[j].strip()
                index += 1
    else:
        pass
studio_reference_unique
# Out:
# ['Bones',
#  'White Fox',
#  'Bandai Namco Pictures',
#  'Madhouse',
#  'Sunrise',
#  'Wit Studio',
#  'Shaft',
#  'Kyoto Animation',
#  'Production I.G',
#  'A-1 Pictures',
#  'Studio Deen',
#  'Artland',
#  'Kinema Citrus',
#  'Studio Pierrot',
#  "Brain's Base",
#  'Tokyo Movie Shinsha',
#  'ufotable',
#  'Gainax',
#  'Shuka',
#  'CloverWorks',
#  'David Production',
#  'Tatsunoko Production',
#  'MAPPA',
#  'J.C.Staff',
#  'Lerche',
#  'TMS Entertainment',
#  'Hal Film Maker',
#  'Toei Animation',
#  'Egg Firm',
#  'feel.',
#  'Manglobe',
#  'OLM',
#  'SynergySP',
#  'Platinum Vision',
#  'Orange',
#  'Nippon Animation',
#  'Studio Signpost',
#  'Zero-G',
#  'Studio Gokumi',
#  'Nakamura Production',
#  'Studio 3Hz',
#  'Animation Do',
#  'Daume',
#  'Telecom Animation Film',
#  'Shin-Ei Animation',
#  'Actas',
#  'Ezόla',
#  'LIDENFILMS',
#  'Hoods Entertainment',
#  'Satelight',
#  'Gonzo',
#  'Palm Studio',
#  'AIC',
#  '8bit',
#  'Nomad',
#  'Fanworks',
#  'Imagineer',
#  'Group TAC',
#  'GoHands',
#  'Seven Arcs',
#  'Zexcs',
#  'AIC Spirits',
#  'Asread',
#  'Doga Kobo',
#  'Xebec',
#  'I.Gzwei',
#  'Fuji TV',
#  'Silver Link.',
#  'SANZIGEN',
#  'Tezuka Productions',
#  'Passione',
#  'Kadokawa',
#  'Bridge',
#  'Bee Train',
#  'Studio VOLN',
#  'Trigger',
#  'Yaoyorozu',
#  'Diomedea',
#  'Shirogumi',
#  'Studio Comet',
#  'TROYCA',
#  'Arms',
#  'Studio Hibari',
#  'C2C',
#  'P.A. Works',
#  'Pierrot Plus',
#  'M.S.C',
#  'AIC ASTA',
#  'Nexus',
#  'Lapin Track',
#  'Nut',
#  'TNK',
#  'Lay-duce',
#  'TYO Animations',
#  'Dongwoo A&E',
#  'The Answer Studio',
#  'Polygon Pictures',
#  'JCF',
#  'Yumeta Company',
#  'Haoliners Animation League',
#  'Tokyo Kids',
#  'Minami Machi Bugyousho',
#  'Picture Magic',
#  'Ordet',
#  'Gallop',
#  'Trans Arts',
#  'Studio PuYUKAI',
#  'Asahi Production',
#  'Marvy Jack',
#  'A.C.G.T.',
#  'Geno Studio',
#  'Mushi Production',
#  'Imagin',
#  'C-Station',
#  'Science SARU',
#  'Ajia-Do',
#  'Encourage Films',
#  'AIC Build',
#  'Connect',
#  'KeyEast',
#  'REALTHING',
#  'Gaina',
#  'Kaname Productions',
#  'Seven',
#  'Enoki Films',
#  'Dai Nippon Printing',
#  'Silver',
#  'Arvo Animation',
#  'Seven Arcs Pictures',
#  'Production Reed',
#  'Telescreen',
#  'Karaku',
#  'Eiken',
#  'Studio Junio',
#  'DLE',
#  'DAX Production',
#  'NAZ',
#  'Studio M2',
#  'Tsuchida Productions',
#  'Magic Bus',
#  'Production IMS',
#  'Animation 21',
#  'Pine Jam',
#  'Japan Vistec',
#  'Kamikaze Douga',
#  'AIC Plus+',
#  'Studio Fantasia',
#  'Shogakukan Music & Digital Entertainment',
#  'Ashi Production',
#  'AIC Classic',
#  'Public & Basic',
#  'Tama Production',
#  'Sparkly Key Animation Studio',
#  'Phoenix Entertainment',
#  'Studio Ghibli',
#  'BeSTACK',
#  'Planet',
#  'Pastel',
#  'Barnum Studio',
#  'Project No.9',
#  'Japan Taps',
#  'ixtl',
#  'Studio Bogey',
#  'Studio 4°C',
#  'AXsiZ',
#  'Kanaban Graphics',
#  'ENGI',
#  'Studio World',
#  'CygamesPictures',
#  'Academy Productions',
#  'ILCA',
#  'Gathering',
#  'CoMix Wave Films',
#  'Maho Film',
#  'Dwango',
#  'Gosay Studio',
#  'Amuse',
#  'E&G Films',
#  'Triangle Staff',
#  'APPP',
#  'Radix',
#  'Remic',
#  'Tomason',
#  'Issen',
#  'Daewon Media',
#  'Creators in Pack',
#  '3xCube',
#  'EMT Squared',
#  'Ginga Ya',
#  'Mook DLE',
#  'WAO World',
#  'Studio Flag',
#  'GEMBA',
#  'Studio Blanc',
#  'Signal.MD',
#  'Revoroot',
#  'Trinet Entertainment',
#  'Future Planet',
#  'Beijing Huihuang Animation Company',
#  'Jinnis Animation Studios',
#  'helo.inc',
#  'Marza Animation Planet',
#  'Felix Film',
#  'Bee Media',
#  'Namu Animation',
#  'Sparky Animation',
#  'Millepensee',
#  'Studio Sign',
#  'Panmedia',
#  'Meruhensha',
#  'Digital Frontier',
#  'PRA',
#  'Plum',
#  'Visual 80',
#  'Graphinica',
#  'Azeta Pictures',
#  'Lesprit',
#  'Hoods Drifters Studio',
#  'Heewon Entertainment',
#  'Yokohama Animation Lab',
#  'Office DCI',
#  'DandeLion Animation Studio',
#  'Studio Egg',
#  'Emon',
#  'Blade',
#  'Milky Cartoon',
#  'GEEK TOYS',
#  'Tele-Cartoon Japan',
#  'Studio A-CAT',
#  'Cookie Jar Entertainment',
#  'Kazami Gakuen Koushiki Douga-bu',
#  'Annapuru',
#  'Team TillDawn',
#  'Studio Live',
#  'View Works',
#  'Studio Hokiboshi',
#  'Team YokkyuFuman',
#  'Echo',
#  'Vega Entertainment',
#  'Anpro',
#  'Studio Flad',
#  'Chaos Project',
#  'HOTZIPANG',
#  'NHK',
#  'Aubec',
#  'EKACHI EPILKA',
#  'production doA',
#  'Studio Zero',
#  'G&G Entertainment',
#  'Tohokushinsha Film Corporation',
#  'Okuruto Noboru',
#  'A-Real',
#  'Tear Studio',
#  'Front Line',
#  'Tokyo Movie',
#  'Tomovies',
#  'Acca effe',
#  'Giga Production',
#  'Animaruya',
#  'Genco',
#  'Kachidoki Studio',
#  'Nihon Ad Systems',
#  'dwarf',
#  'Ark',
#  'Dai-Ichi Douga',
#  'Dongyang Animation',
#  'Albacrow',
#  'Larx Entertainment',
#  'Saetta',
#  'Bibury Animation Studios',
#  'Ishimori Entertainment',
#  'Studio Kyuuma',
#  'Studio Kikan',
#  'Kokusai Eigasha',
#  'DMM.futureworks',
#  'Animation Staff Room',
#  'OLM Digital',
#  "Children's Playground Entertainment",
#  'SBS TV Production',
#  'Drive',
#  'Studio Matrix',
#  'LMD',
#  'Studio Crocodile',
#  'Joker Films',
#  'GANSIS',
#  'Topcraft',
#  'Sanrio',
#  'Knack Productions',
#  'teamKG',
#  'Husio Studio',
#  'Typhoon Graphics',
#  'Studio Wombat',
#  'Studio Nue',
#  'W-Toon Studio',
#  'LandQ studios',
#  'Artmic',
#  'Charaction',
#  'Anima&Co.',
#  'Digital Media Lab',
#  'Amber Film Works',
#  'Cyclone Graphics',
#  'Ascension',
#  'Kate Arrow',
#  'Strawberry Meets Pictures',
#  'Gainax Kyoto',
#  'Bouncy',
#  'IMAGICA Lab.',
#  'RG Animation Studios',
#  'Code',
#  'Ether Kitten',
#  'Sunrise Beyond',
#  'ACC Production',
#  'TUBA',
#  'Hotline',
#  'Creators Dot Com',
#  'B.CMAY PICTURES',
#  'Stingray',
#  'FOREST Hunting One',
#  'Robot Communications',
#  'MASTER LIGHTS',
#  'Rising Force',
#  'Space Neko Company',
#  'Dynamo Pictures',
#  'Tri-Slash',
#  'Opera House',
#  'Peak Hunt',
#  'Wolfsbane',
#  'Studio Lings',
#  'Shanghai Animation Film Studio',
#  'Lilix',
#  'Lide',
#  'Suiseisha',
#  'drop',
#  'Toho Interactive Animation',
#  'AIC Frontier']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

X1 = TV_data["genre_reference_1"].iloc[:3000].to_numpy().reshape(-1,1) #0.20 without
X2 = TV_data["genre_reference_2"].iloc[:3000].to_numpy().reshape(-1,1) #0.18 without
X3 = TV_data["Season"].iloc[:3000].to_numpy().reshape(-1,1) #0.25 without
X4 = TV_data["Source_reference"].iloc[:3000].to_numpy().reshape(-1,1) ##0.12 without
X5 = TV_data['Members'].iloc[:3000].to_numpy().reshape(-1,1) #0.32 without (deg9)
X6 = TV_data['Episodes'].iloc[:3000].to_numpy().reshape(-1,1) #0.39 without, aka useless
X = np.concatenate((X1, X2, X3, X4, X5), axis=1) #0.39 with X1-5 deg2
y = TV_data["Score"].iloc[:3000]

poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)
model = LinearRegression()
model.fit(X_poly, y)

r_sq = model.score(X_poly, y)
print('R^2 score:', r_sq)
# Out:
# R^2 score: 0.3979135348194981

# %% [markdown]
# From this point onwards, we are trying to use manga data to predict the score

# %%
import difflib
str1 = "help season 2"
str2 = "help"
difflib.SequenceMatcher(None, str1, str2).ratio()
# Out:
# 0.47058823529411764

# %%
manga_raw = pd.read_csv(r"C:\Users\user\Desktop\archive\manga.csv")
manga_raw
# Out:
#            id                                              title  \
# 0           1                                            Monster
# 1           2                                            Berserk
# 2           3                                  20th Century Boys
# 3           4                            Yokohama Kaidashi Kikou
# 4           7                                     Hajime no Ippo
# ...       ...                                                ...
# 62789  156479                                       Lolita Meshi
# 62790  156482                                       After School
# 62791  156486                                 Nagisa no Saameido
# 62792  156498                                Susumamire no Kishi
# 62793  156504  Eroge Tensei: Unmei ni Aragau Kane Buta Kizoku...
#
#                       title_en  \
# 0                      Monster
# 1                      Berserk
# 2            20th Century Boys
# 3      Yokohama Kaidashi Kikou
# 4                          NaN
# ...                        ...
# 62789                      NaN
# 62790                      NaN
# 62791                      NaN
# 62792   Knight Covered in Soot
# 62793                      NaN
#
#                                                image_url  chapters  \
# 0      https://cdn.myanimelist.net/images/manga/3/258...       162
# 1      https://cdn.myanimelist.net/images/manga/1/157...         0
# 2      https://cdn.myanimelist.net/images/manga/5/260...       249
# 3      https://cdn.myanimelist.net/images/manga/1/171...       142
# 4      https://cdn.myanimelist.net/images/manga/2/250...         0
# ...                                                  ...       ...
# 62789  https://cdn.myanimelist.net/images/manga/3/277...        33
# 62790  https://cdn.myanimelist.net/images/manga/2/277...         1
# 62791  https://cdn.myanimelist.net/images/manga/1/277...         0
# 62792  https://cdn.myanimelist.net/images/manga/2/277...         0
# 62793  https://cdn.myanimelist.net/images/manga/2/277...         0
#
#        publishing             published_from               published_to  \
# 0           False  1994-12-05T00:00:00+00:00  2001-12-20T00:00:00+00:00
# 1            True  1989-08-25T00:00:00+00:00                        NaN
# 2           False  1999-09-27T00:00:00+00:00  2006-04-24T00:00:00+00:00
# 3           False  1994-04-25T00:00:00+00:00  2006-02-25T00:00:00+00:00
# 4            True  1989-09-27T00:00:00+00:00                        NaN
# ...           ...                        ...                        ...
# 62789       False  2020-03-13T00:00:00+00:00  2021-04-30T00:00:00+00:00
# 62790       False  2021-09-22T00:00:00+00:00                        NaN
# 62791        True  2023-01-27T00:00:00+00:00                        NaN
# 62792        True  2022-05-27T00:00:00+00:00                        NaN
# 62793        True  2022-12-17T00:00:00+00:00                        NaN
#
#        score  scored_by  members  favorites   author
# 0       9.14      83708   214367      18710   1867.0
# 1       9.47     299323   607170     113562   1868.0
# 2       8.95      75431   219385      17375   1867.0
# 3       8.68      16946    67265       4769   1869.0
# 4       8.70      32838    76329       6087   1876.0
# ...      ...        ...      ...        ...      ...
# 62789   0.00          0       10          0  64518.0
# 62790   0.00          0        6          0  64389.0
# 62791   0.00          0       28          0  50056.0
# 62792   0.00          0        7          0  64514.0
# 62793   0.00          0        5          0  64536.0
#
# [62794 rows x 13 columns]

# %%
TV_data_manga
# Out:
#                              Anime Title Type Episodes  \
# 0       Fullmetal Alchemist: Brotherhood   TV       64
# 2                               Gintama°   TV       51
# 3                 Hunter x Hunter (2011)   TV      148
# 5                               Gintama'   TV       51
# 6     Shingeki no Kyojin Season 3 Part 2   TV       10
# ...                                  ...  ...      ...
# 9875        Wild 7 Another Bouryaku Unga   TV       13
# 9902        Nobunaga-sensei no Osanazuma   TV       12
# 9978                           Barom One   TV       13
# 9985      Omae wa Mada Gunma wo Shiranai   TV       12
# 9999              Kamikaze Kaitou Jeanne   TV       44
#
#                              Aired  \
# 0       Apr 5, 2009 to Jul 4, 2010
# 2      Apr 8, 2015 to Mar 30, 2016
# 3      Oct 2, 2011 to Sep 24, 2014
# 5      Apr 4, 2011 to Mar 26, 2012
# 6      Apr 29, 2019 to Jul 1, 2019
# ...                            ...
# 9875  Apr 27, 2002 to Aug 31, 2002
# 9902   Apr 6, 2019 to Jun 22, 2019
# 9978   Dec 7, 2002 to Mar 22, 2003
# 9985   Apr 2, 2018 to Jun 18, 2018
# 9999  Feb 13, 1999 to Jan 29, 2000
#
#                                               Producers  \
# 0     Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 2                             TV Tokyo, Aniplex, Dentsu
# 3              VAP, Nippon Television Network, Shueisha
# 5     TV Tokyo, Aniplex, Dentsu, Trinity Sound, Mira...
# 6     Production I.G, Dentsu, Mainichi Broadcasting ...
# ...                                                 ...
# 9875                                          E&G Films
# 9902                                                NaN
# 9978                                               AT-X
# 9985                                     TOHO animation
# 9999                                                NaN
#
#                     Studios     Source  \
# 0                     Bones      Manga
# 2     Bandai Namco Pictures      Manga
# 3                  Madhouse      Manga
# 5                   Sunrise      Manga
# 6                Wit Studio      Manga
# ...                     ...        ...
# 9875                    NaN      Manga
# 9902                  Seven      Manga
# 9978              E&G Films      Manga
# 9985       Asahi Production  Web manga
# 9999         Toei Animation      Manga
#
#                                                  Genres  Score  Members  \
# 0     Action, Military, Adventure, Comedy, Drama, Ma...   9.22  2025613
# 2     Action, Comedy, Historical, Parody, Samurai, S...   9.11   363879
# 3      Action, Adventure, Fantasy, Shounen, Super Power   9.11  1459320
# 5     Action, Sci-Fi, Comedy, Historical, Parody, Sa...   9.08   337198
# 6     Action, Military, Mystery, Super Power, Drama,...   9.07   815370
# ...                                                 ...    ...      ...
# 9875                 Action, Adventure, Police, Shounen   5.31      715
# 9902              Comedy, Ecchi, Harem, Romance, School   5.29    52359
# 9978              Action, Sci-Fi, Supernatural, Shounen   5.25     1576
# 9985                                     Comedy, School   5.25    11760
# 9999  Adventure, Comedy, Demons, Drama, Fantasy, Mag...   7.45    44497
#
#       Favorites   Fav%  Source_reference
# 0        167812  8.285                 0
# 2         10353  2.845                 0
# 3        130492  8.942                 0
# 5          6013  1.783                 0
# 6         28479  3.493                 0
# ...         ...    ...               ...
# 9875          1  0.140                 0
# 9902         78  0.149                 0
# 9978          1  0.063                 0
# 9985          2  0.017                 0
# 9999        478  1.074                 0
#
# [1656 rows x 13 columns]

# %%
a = [0] * len(TV_data_manga) 
for i in range(len(TV_data_manga)): 
    anime_title = TV_data_manga["Anime Title"].iloc[i] 
    for j in range(len(manga_raw)): 
        manga_title = manga_raw["title"].iloc[j] 
        if(difflib.SequenceMatcher(None, anime_title,manga_title).ratio() > 0.5): 
            a[i] = manga_raw["score"].iloc[j] 
            break 
    print("%d. %f"%(i, a[i]))
# Out:
# 0. 9.040000
# 1. 8.620000
# 2. 8.720000
# 3. 8.620000
# 4. 6.780000
# 5. 8.620000
# 6. 6.970000
# 7. 8.620000
# 8. 8.620000
# 9. 6.970000
# 10. 0.000000
# 11. 0.000000
# 12. 0.000000
# 13. 0.000000
# 14. 8.270000
# 15. 6.970000
# 16. 6.970000
# 17. 7.170000
# 18. 8.290000
# 19. 8.700000
# 20. 9.140000
# 21. 7.640000
# 22. 9.020000
# 23. 7.240000
# 24. 8.730000
# 25. 8.700000
# 26. 6.930000
# 27. 8.160000
# 28. 7.010000
# 29. 6.750000
# 30. 7.900000
# 31. 8.100000
# 32. 7.500000
# 33. 8.700000
# 34. 7.360000
# 35. 9.210000
# 36. 6.380000
# 37. 8.700000
# 38. 7.200000
# 39. 6.970000
# 40. 6.670000
# 41. 8.020000
# 42. 8.670000
# 43. 6.970000
# 44. 8.520000
# 45. 7.580000
# 46. 7.200000
# 47. 8.000000
# 48. 6.890000
# 49. 9.070000
# 50. 7.070000
# 51. 8.620000
# 52. 8.100000
# 53. 6.660000
# 54. 7.620000
# 55. 6.970000
# 56. 9.210000
# 57. 7.780000
# 58. 9.470000
# 59. 7.070000
# 60. 7.630000
# 61. 8.100000
# 62. 7.910000
# 63. 7.310000
# 64. 7.040000
# 65. 8.000000
# 66. 7.990000
# 67. 8.120000
# 68. 7.200000
# 69. 7.320000
# 70. 0.000000
# 71. 7.250000
# 72. 8.200000
# 73. 7.600000
# 74. 6.970000
# 75. 7.000000
# 76. 7.870000
# 77. 8.720000
# 78. 7.420000
# 79. 7.070000
# 80. 6.970000
# 81. 8.400000
# 82. 6.890000
# 83. 8.630000
# 84. 6.970000
# 85. 6.970000
# 86. 6.610000
# 87. 7.720000
# 88. 7.800000
# 89. 7.580000
# 90. 6.220000
# 91. 7.430000
# 92. 7.660000
# 93. 6.820000
# 94. 7.080000
# 95. 8.190000
# 96. 7.180000
# 97. 8.450000
# 98. 7.520000
# 99. 0.000000
# 100. 8.250000
# 101. 8.140000
# 102. 7.070000
# 103. 7.810000
# 104. 7.380000
# 105. 7.720000
# 106. 7.510000
# 107. 7.660000
# 108. 7.570000
# 109. 8.190000
# 110. 8.110000
# 111. 0.000000
# 112. 6.610000
# 113. 8.380000
# 114. 6.950000
# 115. 7.740000
# 116. 0.000000
# 117. 6.600000
# 118. 7.930000
# 119. 7.130000
# 120. 7.780000
# 121. 7.380000
# 122. 8.390000
# 123. 7.400000
# 124. 0.000000
# 125. 7.770000
# 126. 6.870000
# 127. 7.000000
# 128. 7.390000
# 129. 7.990000
# 130. 6.450000
# 131. 7.500000
# 132. 7.950000
# 133. 7.640000
# 134. 8.290000
# 135. 7.380000
# 136. 6.880000
# 137. 7.100000
# 138. 7.990000
# 139. 7.990000
# 140. 6.990000
# 141. 7.400000
# 142. 6.970000
# 143. 7.390000
# 144. 7.300000
# 145. 6.880000
# 146. 7.820000
# 147. 7.050000
# 148. 0.000000
# 149. 7.810000
# 757. 7.320000
# 758. 8.700000
# 759. 7.870000
# 760. 9.470000
# 761. 6.440000
# 762. 6.380000
# 763. 8.210000
# 764. 7.060000
# 765. 0.000000
# 766. 6.970000
# 767. 8.530000
# 768. 8.120000
# 769. 7.570000
# 770. 6.250000
# 771. 7.920000
# 772. 8.340000
# 773. 6.720000
# 774. 7.810000
# 775. 8.720000
# 776. 8.290000
# 777. 7.200000
# 778. 7.090000
# 779. 8.300000
# 780. 8.190000
# 781. 6.820000
# 782. 7.680000
# 783. 7.980000
# 784. 7.020000
# 785. 7.500000
# 786. 7.040000
# 787. 7.280000
# 788. 6.970000
# 789. 7.250000
# 790. 7.290000
# 791. 0.000000
# 792. 6.940000
# 793. 6.920000
# 794. 6.970000
# 795. 7.550000
# 796. 6.980000
# 797. 7.900000
# 798. 7.940000
# 799. 8.160000
# 800. 7.870000
# 801. 0.000000
# 802. 7.700000
# 803. 6.970000
# 804. 7.010000
# 805. 7.170000
# 806. 6.850000
# 807. 7.610000
# 808. 7.020000
# 809. 6.880000
# 810. 6.770000
# 811. 7.370000
# 812. 6.910000
# 813. 8.110000
# 814. 7.570000
# 815. 6.670000
# 816. 6.650000
# 817. 6.920000
# 818. 7.940000
# 819. 7.360000
# 820. 7.500000
# 821. 7.130000
# 822. 6.950000
# 823. 7.260000
# 824. 7.000000
# 825. 7.540000
# 826. 6.610000
# 827. 7.500000
# 828. 7.860000
# 829. 6.730000
# 830. 7.230000
# 831. 7.010000
# 832. 7.780000
# 833. 6.880000
# 834. 7.540000
# 835. 6.810000
# 836. 6.870000
# 837. 9.210000
# 838. 6.920000
# 839. 7.310000
# 840. 7.660000
# 841. 7.270000
# 842. 6.660000
# 843. 7.350000
# 844. 6.350000
# 845. 7.260000
# 846. 0.000000
# 847. 7.320000
# 848. 0.000000
# 849. 7.710000
# 850. 6.950000
# 851. 7.200000
# 852. 7.010000
# 853. 7.930000
# 854. 6.710000
# 855. 8.080000
# 856. 7.410000
# 857. 7.830000
# 858. 4.890000
# 859. 7.010000
# 860. 7.410000
# 861. 8.100000
# 862. 7.130000
# 863. 6.930000
# 864. 0.000000
# 865. 6.870000
# 866. 6.870000
# 867. 7.500000
# 868. 7.930000
# 869. 0.000000
# 870. 6.750000
# 871. 7.030000
# 872. 6.140000
# 873. 7.930000
# 874. 7.920000
# 875. 0.000000
# 876. 7.660000
# 877. 7.320000
# 878. 7.000000
# 879. 7.690000
# 880. 0.000000
# 881. 7.220000
# 882. 6.840000
# 883. 7.140000
# 884. 7.610000
# 885. 7.320000
# 886. 0.000000
# 887. 8.170000
# 888. 8.340000
# 889. 7.620000
# 890. 7.000000
# 891. 6.790000
# 892. 0.000000
# 893. 7.710000
# 894. 6.870000
# 895. 7.830000
# 896. 7.800000
# 897. 8.290000
# 898. 0.000000
# 899. 0.000000
# 900. 6.780000
# 901. 6.560000
# 902. 7.420000
# 903. 7.040000
# 904. 7.610000
# 905. 7.640000
# 906. 7.070000
# 907. 6.660000
# 1606. 6.790000
# 1607. 6.500000
# 1608. 8.070000
# 1609. 6.820000
# 1610. 7.290000
# 1611. 7.800000
# 1612. 0.000000
# 1613. 6.930000
# 1614. 7.860000
# 1615. 6.660000
# 1616. 9.140000
# 1617. 8.170000
# 1618. 7.790000
# 1619. 8.240000
# 1620. 7.420000
# 1621. 7.050000
# 1622. 7.810000
# 1623. 9.210000
# 1624. 7.690000
# 1625. 6.560000
# 1626. 7.140000
# 1627. 7.160000
# 1628. 6.710000
# 1629. 6.610000
# 1630. 6.450000
# 1631. 7.280000
# 1632. 7.560000
# 1633. 0.000000
# 1634. 6.780000
# 1635. 6.600000
# 1636. 6.870000
# 1637. 7.470000
# 1638. 8.130000
# 1639. 6.700000
# 1640. 0.000000
# 1641. 7.290000
# 1642. 7.980000
# 1643. 7.610000
# 1644. 6.920000
# 1645. 0.000000
# 1646. 5.870000
# 1647. 7.190000
# 1648. 7.850000
# 1649. 7.530000
# 1650. 6.600000
# 1651. 0.000000
# 1652. 7.710000
# 1653. 8.300000
# 1654. 7.050000
# 1655. 7.500000

# %%
TV_data_manga = TV_data.loc[TV_data["Source_reference"]==0]
TV_data_manga["Manga_score"]=a
TV_data_manga=TV_data_manga.loc[TV_data_manga["Manga_score"]>0]
TV_data_manga
# Out:
# <ipython-input-27-7513fefd88fb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TV_data_manga["Manga_score"]=a
#                              Anime Title Type Episodes  \
# 0       Fullmetal Alchemist: Brotherhood   TV       64
# 2                               Gintama°   TV       51
# 3                 Hunter x Hunter (2011)   TV      148
# 5                               Gintama'   TV       51
# 6     Shingeki no Kyojin Season 3 Part 2   TV       10
# ...                                  ...  ...      ...
# 9841           Makeruna!! Aku no Gundan!   TV       12
# 9902        Nobunaga-sensei no Osanazuma   TV       12
# 9978                           Barom One   TV       13
# 9985      Omae wa Mada Gunma wo Shiranai   TV       12
# 9999              Kamikaze Kaitou Jeanne   TV       44
#
#                              Aired  \
# 0       Apr 5, 2009 to Jul 4, 2010
# 2      Apr 8, 2015 to Mar 30, 2016
# 3      Oct 2, 2011 to Sep 24, 2014
# 5      Apr 4, 2011 to Mar 26, 2012
# 6      Apr 29, 2019 to Jul 1, 2019
# ...                            ...
# 9841   Apr 5, 2017 to Jun 21, 2017
# 9902   Apr 6, 2019 to Jun 22, 2019
# 9978   Dec 7, 2002 to Mar 22, 2003
# 9985   Apr 2, 2018 to Jun 18, 2018
# 9999  Feb 13, 1999 to Jan 29, 2000
#
#                                               Producers  \
# 0     Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 2                             TV Tokyo, Aniplex, Dentsu
# 3              VAP, Nippon Television Network, Shueisha
# 5     TV Tokyo, Aniplex, Dentsu, Trinity Sound, Mira...
# 6     Production I.G, Dentsu, Mainichi Broadcasting ...
# ...                                                 ...
# 9841                                          Bushiroad
# 9902                                                NaN
# 9978                                               AT-X
# 9985                                     TOHO animation
# 9999                                                NaN
#
#                     Studios     Source  \
# 0                     Bones      Manga
# 2     Bandai Namco Pictures      Manga
# 3                  Madhouse      Manga
# 5                   Sunrise      Manga
# 6                Wit Studio      Manga
# ...                     ...        ...
# 9841   Tatsunoko Production      Manga
# 9902                  Seven      Manga
# 9978              E&G Films      Manga
# 9985       Asahi Production  Web manga
# 9999         Toei Animation      Manga
#
#                                                  Genres  Score  Members  \
# 0     Action, Military, Adventure, Comedy, Drama, Ma...   9.22  2025613
# 2     Action, Comedy, Historical, Parody, Samurai, S...   9.11   363879
# 3      Action, Adventure, Fantasy, Shounen, Super Power   9.11  1459320
# 5     Action, Sci-Fi, Comedy, Historical, Parody, Sa...   9.08   337198
# 6     Action, Military, Mystery, Super Power, Drama,...   9.07   815370
# ...                                                 ...    ...      ...
# 9841                                    Comedy, Shounen   5.33     1628
# 9902              Comedy, Ecchi, Harem, Romance, School   5.29    52359
# 9978              Action, Sci-Fi, Supernatural, Shounen   5.25     1576
# 9985                                     Comedy, School   5.25    11760
# 9999  Adventure, Comedy, Demons, Drama, Fantasy, Mag...   7.45    44497
#
#       Favorites   Fav%  Source_reference  genre_reference_1  \
# 0        167812  8.285                 0                  1
# 2         10353  2.845                 0                  1
# 3        130492  8.942                 0                  1
# 5          6013  1.783                 0                  1
# 6         28479  3.493                 0                  1
# ...         ...    ...               ...                ...
# 9841          0  0.000                 0                  4
# 9902         78  0.149                 0                  4
# 9978          1  0.063                 0                  1
# 9985          2  0.017                 0                  4
# 9999        478  1.074                 0                  3
#
#       genre_reference_2  Season  Manga_score
# 0                     2       2         9.04
# 2                     4       2         8.62
# 3                     3       4         8.72
# 5                    10       2         8.62
# 6                     2       2         6.78
# ...                 ...     ...          ...
# 9841                  8       2         6.60
# 9902                 35       2         7.71
# 9978                 10       4         8.30
# 9985                 24       2         7.05
# 9999                  4       1         7.50
#
# [1522 rows x 17 columns]

# %%
TV_data_1k = TV_data_manga
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

X1 = TV_data_1k["genre_reference_1"].to_numpy().reshape(-1,1)
X2 = TV_data_1k["genre_reference_2"].to_numpy().reshape(-1,1)
X3 = TV_data_1k["Season"].to_numpy().reshape(-1,1) 
X4 = TV_data_1k["Source_reference"].to_numpy().reshape(-1,1) 
X5 = TV_data_1k['Fav%'].to_numpy().reshape(-1,1) 
X6 = TV_data_1k['Episodes'].to_numpy().reshape(-1,1) #0.39 without, aka useless
X7 = TV_data_1k['Manga_score'].to_numpy().reshape(-1,1)
X = np.concatenate((X1, X2, X3, X5, X7), axis=1) 
Y = TV_data_1k["Score"]

max_rsq = 0
best_deg = 0
for i in range(2,10):
    poly = PolynomialFeatures(degree=i)
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)
    X_poly = poly.fit_transform(X_train)
    X_poly_test = poly.fit_transform(X_test)
    model = LinearRegression()
    model.fit(X_poly, Y_train)
    r_sq = model.score(X_poly, Y_train)
    r_sq2 = model.score(X_poly_test, Y_test)
    if r_sq2 <0:
        break
    if r_sq2 > max_rsq:
        max_rsq = r_sq2
        best_deg = i
    print('Train R^2 score:', r_sq, i)
    print('Test R^2 score:', r_sq2)

print('Best R^2 score:', max_rsq, best_deg)
# Out:
# Train R^2 score: 0.4816872893788152 2
# Test R^2 score: 0.5033546887458606
# Train R^2 score: 0.5595543889975358 3
# Test R^2 score: 0.45632425022771494
# Best R^2 score: 0.5033546887458606 2

# %%
revenue = pd.read_csv(r"C:\Users\user\Downloads\someanithing.com (updated through sales week of 2023-01-23) - 2000-Now.csv")
revenue
# Out:
#                            Series Title Type  Season  Year  \
# 0                           .hack//SIGN   TV  Spring  2002
# 1     .hack//Tasogare no Udewa Densetsu   TV  Winter  2003
# 2                          .hack//Roots   TV  Spring  2006
# 3                                 009-1   TV    Fall  2006
# 4                              07-Ghost   TV  Spring  2009
# ...                                 ...  ...     ...   ...
# 2557                     Zettai Shounen   TV  Spring  2005
# 2558                             Zipang   TV    Fall  2004
# 2559                        Zombie-Loan   TV  Summer  2007
# 2560                    Zombieland Saga   TV    Fall  2018
# 2561            Zombieland Saga Revenge   TV  Spring  2021
#
#      Sales Avg, Initial Release Sales Avg, Re-releases Sales Avg, Total  \
# 0                         6,032                      0            6,032
# 1                         2,954                      0            2,954
# 2                         2,138                      0            2,138
# 3                         1,258                      0            1,258
# 4                         2,529                      0            2,529
# ...                         ...                    ...              ...
# 2557                        644                      0              644
# 2558                      1,639                      0            1,639
# 2559                        543                      0              543
# 2560                     20,917                  1,227           22,144
# 2561                      7,757                      0            7,757
#
#      Revenue\n(Initial Release) Source Material        Animation Studio  \
# 0                  ¥362,220,000            game               Bee Train
# 1                  ¥102,810,000            game               Bee Train
# 2                  ¥113,000,000            game               Bee Train
# 3                   ¥46,390,000           manga  Ishimori Entertainment
# 4                  ¥197,230,000           manga             Studio Deen
# ...                         ...             ...                     ...
# 2557                ¥11,590,000        original                 Asia-Do
# 2558               ¥100,310,000           manga             Studio Deen
# 2559                ¥17,930,000           manga                   Xebec
# 2560               ¥878,500,000        original                   MAPPA
# 2561               ¥325,790,000        original                   MAPPA
#
#            Publisher     Distributor       万円
# 0      Bandai Visual   Bandai Visual  ¥36,222
# 1      Bandai Visual   Bandai Visual  ¥10,281
# 2      Bandai Visual   Bandai Visual  ¥11,300
# 3            Aniplex            Sony   ¥4,639
# 4               Avex            Avex  ¥19,723
# ...              ...             ...      ...
# 2557   Bandai Visual   Bandai Visual   ¥1,159
# 2558   Marvelous AQL     Pony Canyon  ¥10,031
# 2559  E-Net Frontier  E-Net Frontier   ¥1,793
# 2560            Avex            Avex  ¥87,850
# 2561            Avex            Avex  ¥32,579
#
# [2562 rows x 13 columns]

# %%
import math
a = [0] * len(TV_data_manga) 
for i in range(len(TV_data_manga)): 
    anime_title = TV_data_manga["Anime Title"].iloc[i] 
    for j in range(len(revenue)): 
        revenue_title = revenue["Series Title"].iloc[j] 
        if(difflib.SequenceMatcher(None, anime_title,revenue_title).ratio() > 0.5): 
            money = revenue["Revenue\n(Initial Release)"].iloc[j] 
            money = money[1:].replace(",","")
            a[i] = math.sqrt(int(money))
            break 
    print("%d. %d"%(i, a[i]))
# Out:
# 0. 5908
# 1. 5908
# 2. 6448
# 3. 28895
# 4. 10593
# 5. 5908
# 6. 5908
# 7. 16500
# 8. 8839
# 9. 15180
# 10. 8414
# 9978                           Barom One   TV       13
# 9985      Omae wa Mada Gunma wo Shiranai   TV       12
# 9999              Kamikaze Kaitou Jeanne   TV       44
#
#                              Aired  \
# 2      Apr 8, 2015 to Mar 30, 2016
# 5      Apr 4, 2011 to Mar 26, 2012
# 6      Apr 29, 2019 to Jul 1, 2019
# 7      Oct 4, 2012 to Mar 28, 2013
# 8     Oct 14, 2017 to Mar 31, 2018
# ...                            ...
# 9841   Apr 5, 2017 to Jun 21, 2017
# 9902   Apr 6, 2019 to Jun 22, 2019
# 9978   Dec 7, 2002 to Mar 22, 2003
# 9985   Apr 2, 2018 to Jun 18, 2018
# 9999  Feb 13, 1999 to Jan 29, 2000
#
#                                               Producers  \
# 2                             TV Tokyo, Aniplex, Dentsu
# 5     TV Tokyo, Aniplex, Dentsu, Trinity Sound, Mira...
# 6     Production I.G, Dentsu, Mainichi Broadcasting ...
# 7      TV Tokyo, Aniplex, Dentsu, Shueisha, Miracle Bus
# 8     Aniplex, Dentsu, NHK, Hakusensha, Asmik Ace, T...
# ...                                                 ...
# 9841                                          Bushiroad
# 9902                                                NaN
# 9978                                               AT-X
# 9985                                     TOHO animation
# 9999                                                NaN
#
#                     Studios     Source  \
# 2     Bandai Namco Pictures      Manga
# 5                   Sunrise      Manga
# 6                Wit Studio      Manga
# 7                   Sunrise      Manga
# 8                     Shaft      Manga
# ...                     ...        ...
# 9841   Tatsunoko Production      Manga
# 9902                  Seven      Manga
# 9978              E&G Films      Manga
# 9985       Asahi Production  Web manga
# 9999         Toei Animation      Manga
#
#                                                  Genres  Score  Members  \
# 2     Action, Comedy, Historical, Parody, Samurai, S...   9.11   363879
# 5     Action, Sci-Fi, Comedy, Historical, Parody, Sa...   9.08   337198
# 6     Action, Military, Mystery, Super Power, Drama,...   9.07   815370
# 7     Action, Comedy, Historical, Parody, Samurai, S...   9.04   204816
# 8                    Drama, Game, Seinen, Slice of Life   9.02   238010
# ...                                                 ...    ...      ...
# 9841                                    Comedy, Shounen   5.33     1628
# 9902              Comedy, Ecchi, Harem, Romance, School   5.29    52359
# 9978              Action, Sci-Fi, Supernatural, Shounen   5.25     1576
# 9985                                     Comedy, School   5.25    11760
# 9999  Adventure, Comedy, Demons, Drama, Fantasy, Mag...   7.45    44497
#
#       Favorites   Fav%  Source_reference  genre_reference_1  \
# 2         10353  2.845                 0                  1
# 5          6013  1.783                 0                  1
# 6         28479  3.493                 0                  1
# 7          2302  1.124                 0                  1
# 8          9854  4.140                 0                  5
# ...         ...    ...               ...                ...
# 9841          0  0.000                 0                  4
# 9902         78  0.149                 0                  4
# 9978          1  0.063                 0                  1
# 9985          2  0.017                 0                  4
# 9999        478  1.074                 0                  3
#
#       genre_reference_2  Season  Manga_score       revenue
# 2                     4       2         8.62   5908.468499
# 5                    10       2         8.62   5908.468499
# 6                     2       2         6.78   6448.255578
# 7                     4       4         8.62  28895.847453
# 8                    16       4         6.97  10593.394168
# ...                 ...     ...          ...           ...
# 9841                  8       2         6.60   1630.950643
# 9902                 35       2         7.71  11017.713011
# 9978                 10       4         8.30   6032.412453
# 9985                 24       2         7.05   1236.931688
# 9999                  4       1         7.50   2007.485990
#
# [1274 rows x 18 columns]

# %%
TV_data_1k = TV_data_manga
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

X1 = TV_data_1k["genre_reference_1"].to_numpy().reshape(-1,1)
X2 = TV_data_1k["genre_reference_2"].to_numpy().reshape(-1,1)
X3 = TV_data_1k["Season"].to_numpy().reshape(-1,1) 
X4 = TV_data_1k["Source_reference"].to_numpy().reshape(-1,1) 
X5 = TV_data_1k['Fav%'].to_numpy().reshape(-1,1) 
X6 = TV_data_1k['Episodes'].to_numpy().reshape(-1,1) #0.39 without, aka useless
X7 = TV_data_1k['Manga_score'].to_numpy().reshape(-1,1)
X8 = (TV_data_1k['revenue']).to_numpy().reshape(-1,1)
X = np.concatenate((X1, X2, X3, X5, X7, X8), axis=1) 
Y = TV_data_1k["Score"]

max_rsq = 0
best_deg = 0
for i in range(2,10):
    poly = PolynomialFeatures(degree=i)
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)
    X_poly = poly.fit_transform(X_train)
    X_poly_test = poly.fit_transform(X_test)
    model = LinearRegression()
    model.fit(X_poly, Y_train)
    r_sq = model.score(X_poly, Y_train)
    r_sq2 = model.score(X_poly_test, Y_test)
    if r_sq2 <0:
        break
    if r_sq2 > max_rsq:
        max_rsq = r_sq2
        best_deg = i
    print('Train R^2 score:', r_sq, i)
    print('Test R^2 score:', r_sq2)

print('Best R^2 score:', max_rsq, best_deg)
# Out:
# Train R^2 score: 0.5234689304370274 2
# Test R^2 score: 0.43715210156829265
# Train R^2 score: 0.5376757175165868 3
# Test R^2 score: 0.48840977383358053
# Train R^2 score: 0.49249672236998776 4
# Test R^2 score: 0.3498972509346566
# Best R^2 score: 0.48840977383358053 3

# %%
sb.histplot(data=TV_data_manga, x="revenue", y="Score", kde=True)
# Out:
# <AxesSubplot:xlabel='revenue', ylabel='Score'>

# %%
TV_data_manga.insert(loc = 1, column = "Score_reference", value = "Medium")

# %%
for i in range(len(TV_data_manga)):
    if TV_data_manga["Manga_score"].iloc[i] >8:
        TV_data_manga["Score_reference"].iloc[i] = "High"
    if TV_data_manga["Manga_score"].iloc[i] <6:
        TV_data_manga["Score_reference"].iloc[i] = "Low" #SCORE REFERENCE IS FROM MANGA SCORE

# %%
decTree(TV_data_manga["Score_reference"].to_numpy().reshape(-1,1),TV_data_manga["Source_reference"].to_numpy().reshape(-1,1),3)
# Out:
# <ipython-input-11-8b9e60ab67fd>:13: RuntimeWarning: invalid value encountered in longlong_scalars
#   TP = cm[1][1]/(cm[1][1] + cm[1][0])
# <ipython-input-11-8b9e60ab67fd>:14: RuntimeWarning: invalid value encountered in longlong_scalars
#   FP = cm[0][1]/(cm[0][1] + cm[0][0])
# <ipython-input-11-8b9e60ab67fd>:16: RuntimeWarning: invalid value encountered in longlong_scalars
#   TP1 = cm1[1][1]/(cm1[1][1] + cm1[1][0])
# <ipython-input-11-8b9e60ab67fd>:17: RuntimeWarning: invalid value encountered in longlong_scalars
#   FP1 = cm1[0][1]/(cm1[0][1] + cm1[0][0])
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.7998037291462218
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.8196078431372549
