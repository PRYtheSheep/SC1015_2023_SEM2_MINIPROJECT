# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import difflib as dl

# %%
raw_manga = pd.read_csv(r"manga.csv")
raw_manga.head()
# Out:
#    id                    title                 title_en  \
# 0   1                  Monster                  Monster
# 1   2                  Berserk                  Berserk
# 2   3        20th Century Boys        20th Century Boys
# 3   4  Yokohama Kaidashi Kikou  Yokohama Kaidashi Kikou
# 4   7           Hajime no Ippo                      NaN
#
#                                            image_url  chapters  publishing  \
# 0  https://cdn.myanimelist.net/images/manga/3/258...       162       False
# 1  https://cdn.myanimelist.net/images/manga/1/157...         0        True
# 2  https://cdn.myanimelist.net/images/manga/5/260...       249       False
# 3  https://cdn.myanimelist.net/images/manga/1/171...       142       False
# 4  https://cdn.myanimelist.net/images/manga/2/250...         0        True
#
#               published_from               published_to  score  scored_by  \
# 0  1994-12-05T00:00:00+00:00  2001-12-20T00:00:00+00:00   9.14      83708
# 1  1989-08-25T00:00:00+00:00                        NaN   9.47     299323
# 2  1999-09-27T00:00:00+00:00  2006-04-24T00:00:00+00:00   8.95      75431
# 3  1994-04-25T00:00:00+00:00  2006-02-25T00:00:00+00:00   8.68      16946
# 4  1989-09-27T00:00:00+00:00                        NaN   8.70      32838
#
#    members  favorites  author
# 0   214367      18710  1867.0
# 1   607170     113562  1868.0
# 2   219385      17375  1867.0
# 3    67265       4769  1869.0
# 4    76329       6087  1876.0

# %%
raw_data = pd.read_csv(r"MAL Anime Top 10000 Details.csv")
raw_data.head()
# Out:
#                         Anime Title  \
# 0  Fullmetal Alchemist: Brotherhood
# 1                       Steins;Gate
# 2                          Gintama°
# 3            Hunter x Hunter (2011)
# 4              Ginga Eiyuu Densetsu
#
#                                              MAL Url  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...
# 1     https://myanimelist.net/anime/9253/Steins_Gate
# 2       https://myanimelist.net/anime/28977/Gintama°
# 3  https://myanimelist.net/anime/11061/Hunter_x_H...
# 4  https://myanimelist.net/anime/820/Ginga_Eiyuu_...
#
#                             English                    Japanese Type Episodes  \
# 0  Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST   TV       64
# 1                       Steins;Gate                 STEINS;GATE   TV       24
# 2                  Gintama Season 4                         銀魂°   TV       51
# 3                   Hunter x Hunter    HUNTER×HUNTER（ハンター×ハンター）   TV      148
# 4     Legend of the Galactic Heroes                      銀河英雄伝説  OVA      110
#
#             Status                        Aired    Premiered  \
# 0  Finished Airing   Apr 5, 2009 to Jul 4, 2010  Spring 2009
# 1  Finished Airing  Apr 6, 2011 to Sep 14, 2011  Spring 2011
# 2  Finished Airing  Apr 8, 2015 to Mar 30, 2016  Spring 2015
# 3  Finished Airing  Oct 2, 2011 to Sep 24, 2014    Fall 2011
# 4  Finished Airing  Jan 8, 1988 to Mar 17, 1997          NaN
#
#                    Broadcast  ...        Source  \
# 0     Sundays at 17:00 (JST)  ...         Manga
# 1  Wednesdays at 02:05 (JST)  ...  Visual novel
# 2  Wednesdays at 18:00 (JST)  ...         Manga
# 3     Sundays at 10:55 (JST)  ...         Manga
# 4                        NaN  ...         Novel
#
#                                               Genres         Duration  \
# 0  Action, Military, Adventure, Comedy, Drama, Ma...  24 min. per ep.
# 1                                   Thriller, Sci-Fi  24 min. per ep.
# 2  Action, Comedy, Historical, Parody, Samurai, S...  24 min. per ep.
# 3   Action, Adventure, Fantasy, Shounen, Super Power  23 min. per ep.
# 4                     Military, Sci-Fi, Space, Drama  26 min. per ep.
#
#                            Rating Score Ranking Popularity  Members  \
# 0  R - 17+ (violence & profanity)  9.22       1          4  2025613
# 1       PG-13 - Teens 13 or older  9.12       2          8  1636151
# 2       PG-13 - Teens 13 or older  9.11       3        330   363879
# 3       PG-13 - Teens 13 or older  9.11       4         14  1459320
# 4  R - 17+ (violence & profanity)  9.10       5        629   212162
#
#    Favorites                                            Summary
# 0     167812  "In order for something to be obtained, someth...
# 1     139909  The self-proclaimed mad scientist Rintarou Oka...
# 2      10353  Gintoki, Shinpachi, and Kagura return as the f...
# 3     130492  Hunter x Hunter is set in a world where Hunter...
# 4      13100  The 150-year-long stalemate between the two in...
#
# [5 rows x 23 columns]

# %%
anime = raw_data["Anime Title"]
anime
# Out:
# 0             Fullmetal Alchemist: Brotherhood
# 1                                  Steins;Gate
# 2                                     Gintama°
# 3                       Hunter x Hunter (2011)
# 4                         Ginga Eiyuu Densetsu
#                          ...
# 9995                        Roba Chotto Suneta
# 9996    Ski Jumping Pairs: Road to Torino 2006
# 9997                   Tentoumushi no Otomurai
# 9998          The Baby Birds of Norman McLaren
# 9999                    Kamikaze Kaitou Jeanne
# Name: Anime Title, Length: 10000, dtype: object

# %%
manga = raw_manga["title"]
manga
# Out:
# 0                                                  Monster
# 1                                                  Berserk
# 2                                        20th Century Boys
# 3                                  Yokohama Kaidashi Kikou
# 4                                           Hajime no Ippo
#                                ...
# 62789                                         Lolita Meshi
# 62790                                         After School
# 62791                                   Nagisa no Saameido
# 62792                                  Susumamire no Kishi
# 62793    Eroge Tensei: Unmei ni Aragau Kane Buta Kizoku...
# Name: title, Length: 62794, dtype: object

# %%
a = [0]*len(manga)
anime_set = set(anime)
for i in range(len(manga)):
    if manga[i] in anime_set:
        a[i] = 1
    else:
        a[i] = 0
raw_manga["anime adaptation"] = a

# %%
raw_manga.head(50)
# Out:
#     id                                    title  \
# 0    1                                  Monster
# 1    2                                  Berserk
# 2    3                        20th Century Boys
# 3    4                  Yokohama Kaidashi Kikou
# 4    7                           Hajime no Ippo
# 5    8                   Full Moon wo Sagashite
# 6    9             Tsubasa: RESERVoir CHRoNiCLE
# 7   10                                 xxxHOLiC
# 8   11                                   Naruto
# 9   12                                   Bleach
# 10  13                                One Piece
# 11  14                                     Rave
# 12  15                     Mahou Sensei Negima!
# 13  16                                Love Hina
# 14  17                  Kareshi Kanojo no Jijou
# 15  18                         Kodomo no Omocha
# 16  19                               GetBackers
# 17  20                             Hikaru no Go
# 18  21                               Death Note
# 19  22  Rurouni Kenshin: Meiji Kenkaku Romantan
# 20  23                                  Ranma ½
# 21  24                               D.Gray-man
# 22  25                      Fullmetal Alchemist
# 23  26                          Hunter x Hunter
# 24  27                                        X
# 25  28                                     Nana
# 26  29                            Paradise Kiss
# 27  30                   Ouran Koukou Host Club
# 28  31                           Lovely★Complex
# 29  32                                666 Satan
# 30  33                                 Pita-Ten
# 31  34   Di Gi Charat: Koushiki Comic Anthology
# 32  35                          Kamichama Karin
# 33  36                   Kamikaze Kaitou Jeanne
# 34  37                     Shinshi Doumei Cross
# 35  38                                   #NAME?
# 36  39                           Zombie Powder.
# 37  40                                Black Cat
# 38  41                             Busou Renkin
# 39  42                              Dragon Ball
# 40  43                             Eyeshield 21
# 41  44                                  Gintama
# 42  45                              Ichigo 100%
# 43  46                                  Kannade
# 44  47                   Katekyo Hitman Reborn!
# 45  48                              Pretty Face
# 46  49                      Tennis no Ouji-sama
# 47  50                              Shaman King
# 48  51                                Slam Dunk
# 49  52                                 Whistle!
#
#                                            title_en  \
# 0                                           Monster
# 1                                           Berserk
# 2                                 20th Century Boys
# 3                           Yokohama Kaidashi Kikou
# 4                                               NaN
# 5                            Full Moon wo Sagashite
# 6                      Tsubasa: RESERVoir CHRoNiCLE
# 7                                          xxxHOLiC
# 8                                            Naruto
# 9                                            Bleach
# 10                                        One Piece
# 11                                      Rave Master
# 12                       Negima! Magister Negi Magi
# 13                                        Love Hina
# 14             Kare Kano: His and Her Circumstances
# 15                            Kodocha: Sana's Stage
# 16                                       GetBackers
# 17                                     Hikaru no Go
# 18                                       Death Note
# 19  Rurouni Kenshin: Meiji Swordsman Romantic Story
# 20                                        Ranma 1/2
# 21                                       D.Gray-man
# 22                              Fullmetal Alchemist
# 23                                  Hunter x Hunter
# 24                                                X
# 25                                             Nana
# 26                                    Paradise Kiss
# 27                      Ouran High School Host Club
# 28                                         Love★Com
# 29                                   O-Parts Hunter
# 30                                         Pita-Ten
# 31                                     Di Gi Charat
# 32                                  Kamichama Karin
# 33                             Phantom Thief Jeanne
# 34                   The Gentleman's Alliance Cross
# 35                                           #NAME?
# 36                                    Zombiepowder.
# 37                                        Black Cat
# 38                                      Buso Renkin
# 39                                      Dragon Ball
# 40                                     Eyeshield 21
# 41                                         Gin Tama
# 42                                  Strawberry 100%
# 43                                              NaN
# 44                                          Reborn!
# 45                                      Pretty Face
# 46                                 Prince of Tennis
# 47                                      Shaman King
# 48                                        Slam Dunk
# 49                                         Whistle!
#
#                                             image_url  chapters  publishing  \
# 0   https://cdn.myanimelist.net/images/manga/3/258...       162       False
# 1   https://cdn.myanimelist.net/images/manga/1/157...         0        True
# 2   https://cdn.myanimelist.net/images/manga/5/260...       249       False
# 3   https://cdn.myanimelist.net/images/manga/1/171...       142       False
# 4   https://cdn.myanimelist.net/images/manga/2/250...         0        True
# 5   https://cdn.myanimelist.net/images/manga/3/175...        35       False
# 6   https://cdn.myanimelist.net/images/manga/1/272...       233       False
# 7   https://cdn.myanimelist.net/images/manga/3/217...       213       False
# 8   https://cdn.myanimelist.net/images/manga/3/249...       700       False
# 9   https://cdn.myanimelist.net/images/manga/3/180...       705       False
# 10  https://cdn.myanimelist.net/images/manga/2/253...         0        True
# 11  https://cdn.myanimelist.net/images/manga/3/255...       298       False
# 12  https://cdn.myanimelist.net/images/manga/1/259...       355       False
# 13  https://cdn.myanimelist.net/images/manga/1/259...       120       False
# 14  https://cdn.myanimelist.net/images/manga/1/267...       108       False
# 15  https://cdn.myanimelist.net/images/manga/1/267...        54       False
# 16  https://cdn.myanimelist.net/images/manga/1/169...       344       False
# 17  https://cdn.myanimelist.net/images/manga/2/170...       198       False
# 18  https://cdn.myanimelist.net/images/manga/1/258...       108       False
# 49  1998-02-24T00:00:00+00:00  2002-10-08T00:00:00+00:00   7.79       2616
#
#     members  favorites  author  anime adaptation
# 0    214367      18710  1867.0                 1
# 1    607170     113562  1868.0                 1
# 2    219385      17375  1867.0                 0
# 3     67265       4769  1869.0                 1
# 4     76329       6087  1876.0                 1
# 5     35811       1874  1878.0                 1
# 6     76400       6122  1877.0                 0
# 7     78307       4884  1877.0                 1
# 8    393962      42815  1879.0                 1
# 9    355861      33741  1880.0                 1
# 10   548929     107065  1881.0                 1
# 11    48214       2064  1882.0                 0
# 12    71830       5017  1883.0                 1
# 13    65454       3900  1883.0                 1
# 14    36660       1593  1885.0                 1
# 15    20907       1123  1884.0                 1
# 16    13994        397  1886.0                 1
# 17    43587       1917  1888.0                 1
# 18   370779      30874  1888.0                 1
# 19    91867       7006  1890.0                 1
# 20    47638       2866  1891.0                 1
# 21   149364      12190  1892.0                 1
# 22   276453      29187  1874.0                 1
# 23   247628      21929  1893.0                 1
# 24    23241        974  1877.0                 1
# 25   121696      10276  1894.0                 1
# 26    46742       2346  1894.0                 1
# 27   121671       7884  1895.0                 1
# 28    59546       2690  1896.0                 1
# 29    33559       1034  1897.0                 0
# 30     7793        278  1898.0                 0
# 31     1582         17  1898.0                 0
# 32    11855        300  1898.0                 1
# 33    19162        800  1878.0                 1
# 34    25580       1059  1878.0                 0
# 35    20392        884  1899.0                 0
# 36    14893        249  1880.0                 0
# 37    46628       1739  1900.0                 0
# 38    16400        227  1890.0                 1
# 39   145792      13465  1901.0                 1
# 40    72268       4291  1902.0                 1
# 41    89779       8154  1904.0                 1
# 42    46125       1997  1905.0                 1
# 43      393          0  1906.0                 0
# 44   118564       9643  1907.0                 1
# 45    18335        510  1908.0                 0
# 46    24928        854  1909.0                 1
# 47    70689       3302  1910.0                 1
# 48   147959      14064  1911.0                 1
# 49     5630        157  1912.0                 1

# %%
compare = pd.DataFrame(columns=['franchise','manga score'])

# %%
#cutoff ratio = 0.5

# %%
manga_copy = manga_copy[manga_copy["anime adaptation"] != 0].reset_index(drop=True)

manga_copy
# Out:
#           id                             title  \
# 0          1                           Monster
# 1          2                           Berserk
# 2          4           Yokohama Kaidashi Kikou
# 3          7                    Hajime no Ippo
# 4          8            Full Moon wo Sagashite
# ...      ...                               ...
# 2623  154990  Kumo no Mukou, Yakusoku no Basho
# 2624  155222                      Onegai☆Twins
# 2625  155619               Gakkyuu Ou Yamazaki
# 2626  155656                  Hyperventilation
# 2627  155874    Psycho-Pass 3: First Inspector
#
#                                   title_en  \
# 0                                  Monster
# 1                                  Berserk
# 2                  Yokohama Kaidashi Kikou
# 3                                      NaN
# 4                   Full Moon wo Sagashite
# ...                                    ...
# 2623  The Place Promised in Our Early Days
# 2624                          Please Twins
# 2625                                   NaN
# 2626                                   NaN
# 2627                                   NaN
#
#                                               image_url  chapters  publishing  \
# 0     https://cdn.myanimelist.net/images/manga/3/258...       162       False
# 1     https://cdn.myanimelist.net/images/manga/1/157...         0        True
# 2     https://cdn.myanimelist.net/images/manga/1/171...       142       False
# 3     https://cdn.myanimelist.net/images/manga/2/250...         0        True
# 4     https://cdn.myanimelist.net/images/manga/3/175...        35       False
# ...                                                 ...       ...         ...
# 2623  https://cdn.myanimelist.net/images/manga/3/275...         4       False
# 2624  https://cdn.myanimelist.net/images/manga/2/275...         0       False
# 2625  https://cdn.myanimelist.net/images/manga/1/276...         0       False
# 2626  https://cdn.myanimelist.net/images/manga/1/276...         0       False
# 2627  https://cdn.myanimelist.net/images/manga/1/276...        11       False
#
#                  published_from               published_to  score  scored_by  \
# 0     1994-12-05T00:00:00+00:00  2001-12-20T00:00:00+00:00   9.14      83708
# 1     1989-08-25T00:00:00+00:00                        NaN   9.47     299323
# 2     1994-04-25T00:00:00+00:00  2006-02-25T00:00:00+00:00   8.68      16946
# 3     1989-09-27T00:00:00+00:00                        NaN   8.70      32838
# 4     2001-12-01T00:00:00+00:00  2004-04-30T00:00:00+00:00   8.04      18184
# ...                         ...                        ...    ...        ...
# 2623  2005-12-26T00:00:00+00:00                        NaN   0.00          0
# 2624  2003-11-01T00:00:00+00:00  2004-01-05T00:00:00+00:00   0.00          0
# 2625  1995-09-01T00:00:00+00:00  2001-02-01T00:00:00+00:00   0.00          0
# 2626  2018-01-01T00:00:00+00:00                        NaN   0.00          0
# 2627  2021-10-30T00:00:00+00:00  2022-07-30T00:00:00+00:00   0.00          0
#
#       members  favorites   author  anime adaptation
# 0      214367      18710   1867.0                 1
# 1      607170     113562   1868.0                 1
# 2       67265       4769   1869.0                 1
# 3       76329       6087   1876.0                 1
# 4       35811       1874   1878.0                 1
# ...       ...        ...      ...               ...
# 2623       19          0  38605.0                 1
# 2624        0          0      NaN                 1
# 2625        0          0      NaN                 1
# 2626        0          1      NaN                 1
# 2627       22          1   4931.0                 1
#
# [2628 rows x 14 columns]

# %%
def merge_avg(manga_copy, compare):
    word = manga_copy.iloc[0]["title"]
    temp = {}
    temp.update({word:manga_copy.iloc[0]["score"]})
    
    manga_copy_new = manga_copy.drop(index=0)
    
    for j in range(len(manga_copy_new)):
        see = similiar(word, manga_copy_new.iloc[j]["title"])
        if (see>=0.5):
            temp.update({manga_copy_new.iloc[j]["title"]:manga_copy_new.iloc[j]["score"]})
    
    dftemp = pd.DataFrame(temp, index=[0])
    avg = dftemp.mean(axis=1)[0]
    if dftemp.iloc[1] is None:
        name = dftemp.iloc[0,0]
    else:
        name = SequenceMatcher(None, dftemp.iloc[0, 0], dftemp.iloc[1, 0]).get_matching_blocks()     
    compare = compare.append(avg, ignore_index=True)
    compare.index = [name]

# %%
while manga_copy is not None:
    if manga_copy.empty:
        break
    merge_avg(manga_copy, compare)
    manga_copy.reset_index(drop=True, inplace=True)
    manga_copy.dropna(axis=1, how='all', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17836\4056831564.py in <module>
#       2     if manga_copy.empty:
#       3         break
# ----> 4     merge_avg(manga_copy, compare)
#       5     manga_copy.reset_index(drop=True, inplace=True)
#       6     manga_copy.dropna(axis=1, how='all', inplace=True)
#
# ~\AppData\Local\Temp\ipykernel_17836\1450426878.py in merge_avg(manga_copy, compare)
#       4     temp.update({word:manga_copy.iloc[0]["score"]})
#       5
# ----> 6     manga_copy_new = manga_copy.drop(index=0)
#       7
#       8     for j in range(len(manga_copy_new)):
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: '[0] not found in axis'
